# %% [markdown]
# <a href="https://colab.research.google.com/github/ferraa1/AtividadesPython/blob/main/Copy_of_Aula1_Regress%C3%A3o_Linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # scikit-learn

# %%
from IPython.display import Image
Image('ml_map.png')

# %% [markdown]
# ## Regressão Linear Simples

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np

temperaturas = np.array(range(0, 40, 2))
temperaturas = temperaturas.reshape(-1, 1)
vendas = [65, 58, 46, 45, 44, 42, 40, 40, 36, 38, 38, 28, 30, 22, 27, 25, 25, 20, 15, 5]

plt.plot(temperaturas, vendas, 'o')
plt.show()

# %%
regressaoLinear = LinearRegression()

# %%
# Treinando o modelo
regressaoLinear.fit(temperaturas,vendas)
# Out:
# LinearRegression()

# %%
previsao_vendas = regressaoLinear.predict(temperaturas)
plt.plot(temperaturas, vendas, 'o')
plt.plot(temperaturas,previsao_vendas)
plt.show()

# %%
#Prevendo o número de casacos vendidos
print("%.2f" %regressaoLinear.predict([[43]]))
# Out:
# 6.80

# %%
regressaoLinear.coef_
# Out:
# array([-1.15225564])

# %%
regressaoLinear.intercept_
# Out:
# 56.342857142857156

# %% [markdown]
# ### Coficiente de determinação (R²)

# %%
Image('r2.png')

# %% [markdown]
# #### ŷ representa o valor predito, y_barra representa o valor médio das amostras e yi representa o valor real.

# %%
Image('r2_gráficos.png')

# %% [markdown]
# #### Na imagem acima, podemos ver que se o modelo (reta) não se distancia muito dos dados, temos um valor de R-Quadrado alto (gráfico 1), em contraste com o gráfico 2.

# %%
# em metrics, temos quase todas as metricas geralmete utilizadas
from sklearn.metrics import r2_score 

R2 = r2_score(vendas,previsao_vendas)
print(R2)
# Out:
# 0.9114088011031334

# %% [markdown]
# ## Regressão Linear Múltipla

# %%
import pandas as pd

# %%
moradias = pd.read_csv('moradias.csv')
moradias.head()
# Out:
#    rental_id   rent  bedrooms  bathrooms  size_sqft  min_to_subway  floor  \
# 0       1545   2550       0.0          1        480              9    2.0
# 1       2472  11500       2.0          2       2000              4    1.0
# 2       2919   4500       1.0          1        916              2   51.0
# 3       2790   4795       1.0          1        975              3    8.0
# 4       3946  17500       2.0          2       4800              3    4.0
#
#    building_age_yrs  no_fee  has_roofdeck  has_washer_dryer  has_doorman  \
# 0                17       1             1                 0            0
# 1                96       0             0                 0            0
# 2                29       0             1                 0            1
# 3                31       0             0                 0            1
# 4               136       0             0                 0            1
#
#    has_elevator  has_dishwasher  has_patio  has_gym       neighborhood  \
# 0             1               1          0        1    Upper East Side
# 1             0               0          0        0  Greenwich Village
# 2             1               1          0        0            Midtown
# 3             1               1          0        1  Greenwich Village
# 4             1               1          0        1               Soho
#
#      borough
# 0  Manhattan
# 1  Manhattan
# 2  Manhattan
# 3  Manhattan
# 4  Manhattan

# %%
moradias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3539 entries, 0 to 3538
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rental_id         3539 non-null   int64
#  1   rent              3539 non-null   int64
#  2   bedrooms          3539 non-null   float64
#  3   bathrooms         3539 non-null   int64
#  4   size_sqft         3539 non-null   int64
#  5   min_to_subway     3539 non-null   int64
#  6   floor             3539 non-null   float64
#  7   building_age_yrs  3539 non-null   int64
#  8   no_fee            3539 non-null   int64
#  9   has_roofdeck      3539 non-null   int64
#  10  has_washer_dryer  3539 non-null   int64
#  11  has_doorman       3539 non-null   int64
#  12  has_elevator      3539 non-null   int64
#  13  has_dishwasher    3539 non-null   int64
#  14  has_patio         3539 non-null   int64
#  15  has_gym           3539 non-null   int64
#  16  neighborhood      3539 non-null   object
#  17  borough           3539 non-null   object
# dtypes: float64(2), int64(14), object(2)
# memory usage: 497.8+ KB

# %%
x = moradias[['bedrooms', 'bathrooms', 'size_sqft', 'min_to_subway', 'floor', 'building_age_yrs', 'no_fee', 'has_roofdeck', 'has_washer_dryer', 'has_doorman', 'has_elevator', 'has_dishwasher', 'has_patio', 'has_gym']]
y = moradias[['rent']]

# %%
#Dividindo o conjunto entre treinamento e teste
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2831, 14)
# (708, 14)
# (2831, 1)
# (708, 1)

# %%
regressaoMultipla = LinearRegression()
regressaoMultipla.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
dadosImovel = [[1, 1, 620, 16, 1, 98, 1, 0, 1, 0, 0, 1, 1, 0]]

previsao_aluguel = regressaoMultipla.predict(dadosImovel)

print("Previsão preço do Aluguel: $%.2f" % previsao_aluguel)
# Out:
# Previsão preço do Aluguel: $2459.03

# %%
y_previsto = regressaoMultipla.predict(x_test)

# %%
plt.scatter(y_test, y_previsto)

plt.xlabel("Preços: $Y_i$")
plt.ylabel("Previsão Preços: $\hat{Y}_i$")
plt.title("Aluguel Real vs Aluguel Previsto")

plt.show()

# %%
#Coficiente de determinação (R²)
R2 = r2_score(y_test,y_previsto)
print(R2)
# Out:
# 0.7872099003554064

# %%
moradias.corr()
# Out:
#                   rental_id      rent  bedrooms  bathrooms  size_sqft  \
# rental_id          1.000000 -0.134347 -0.070290  -0.109414  -0.107711
# rent              -0.134347  1.000000  0.638336   0.769474   0.857954
# bedrooms          -0.070290  0.638336  1.000000   0.720885   0.771263
# bathrooms         -0.109414  0.769474  0.720885   1.000000   0.803627
# size_sqft         -0.107711  0.857954  0.771263   0.803627   1.000000
# min_to_subway      0.009615  0.035164  0.076543   0.086932   0.039448
# floor             -0.082586  0.215867  0.043539   0.127969   0.107186
# building_age_yrs   0.028543 -0.128895  0.037228  -0.095421   0.014489
# no_fee             0.064919 -0.101497 -0.100352  -0.062205  -0.141451
# has_roofdeck      -0.023335  0.035165  0.002938   0.019556   0.024822
# has_washer_dryer  -0.072738  0.053873  0.008721   0.025752   0.038263
# has_doorman       -0.057786  0.031302 -0.017331   0.014745   0.026098
# has_elevator      -0.060152  0.051860 -0.006771   0.021150   0.040916
# has_dishwasher    -0.029615  0.052241  0.005467   0.038829   0.050364
# has_patio         -0.004253  0.029302  0.003037   0.042304   0.021921
# has_gym           -0.023457  0.040609 -0.004112   0.029739   0.029347
#
#                   min_to_subway     floor  building_age_yrs    no_fee  \
# rental_id              0.009615 -0.082586          0.028543  0.064919
# rent                   0.035164  0.215867         -0.128895 -0.101497
# bedrooms               0.076543  0.043539          0.037228 -0.100352
# bathrooms              0.086932  0.127969         -0.095421 -0.062205
# size_sqft              0.039448  0.107186          0.014489 -0.141451
# min_to_subway          1.000000  0.082445         -0.184682  0.080088
# floor                  0.082445  1.000000         -0.389260  0.104317
# building_age_yrs      -0.184682 -0.389260          1.000000 -0.221429
# no_fee                 0.080088  0.104317         -0.221429  1.000000
# has_roofdeck          -0.020693  0.056322         -0.041305 -0.095718
# has_washer_dryer      -0.001327  0.038870         -0.030014 -0.070324
# has_doorman           -0.009012  0.095963         -0.047265 -0.182547
# has_elevator          -0.000410  0.068917         -0.060627 -0.161519
# has_dishwasher        -0.012244  0.002337         -0.027420 -0.078660
# has_patio              0.001500  0.059423         -0.050321 -0.049684
# has_gym               -0.004315  0.065410         -0.063110 -0.101230
#
#                   has_roofdeck  has_washer_dryer  has_doorman  has_elevator  \
# rental_id            -0.023335         -0.072738    -0.057786     -0.060152
# rent                  0.035165          0.053873     0.031302      0.051860
# bedrooms              0.002938          0.008721    -0.017331     -0.006771
# bathrooms             0.019556          0.025752     0.014745      0.021150
# size_sqft             0.024822          0.038263     0.026098      0.040916
# min_to_subway        -0.020693         -0.001327    -0.009012     -0.000410
# floor                 0.056322          0.038870     0.095963      0.068917
# building_age_yrs     -0.041305         -0.030014    -0.047265     -0.060627
# no_fee               -0.095718         -0.070324    -0.182547     -0.161519
# has_roofdeck          1.000000          0.313459     0.489836      0.516534
# has_washer_dryer      0.313459          1.000000     0.328291      0.379999
# has_doorman           0.489836          0.328291     1.000000      0.717929
# has_elevator          0.516534          0.379999     0.717929      1.000000
# has_dishwasher        0.331999          0.455166     0.343159      0.419812
# has_patio             0.122568          0.140979     0.140968      0.134536
# has_gym               0.561626          0.348433     0.633628      0.642099
#
#                   has_dishwasher  has_patio   has_gym
# rental_id              -0.029615  -0.004253 -0.023457
# rent                    0.052241   0.029302  0.040609
# bedrooms                0.005467   0.003037 -0.004112
# bathrooms               0.038829   0.042304  0.029739
# size_sqft               0.050364   0.021921  0.029347
# min_to_subway          -0.012244   0.001500 -0.004315
# floor                   0.002337   0.059423  0.065410
# building_age_yrs       -0.027420  -0.050321 -0.063110
# no_fee                 -0.078660  -0.049684 -0.101230
# has_roofdeck            0.331999   0.122568  0.561626
# has_washer_dryer        0.455166   0.140979  0.348433
# has_doorman             0.343159   0.140968  0.633628
# has_elevator            0.419812   0.134536  0.642099
# has_dishwasher          1.000000   0.133127  0.342590
# has_patio               0.133127   1.000000  0.123524
# has_gym                 0.342590   0.123524  1.000000

# %%
corr = moradias.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_05f0e_row0_col0,#T_05f0e_row1_col1,#T_05f0e_row2_col2,#T_05f0e_row3_col3,#T_05f0e_row4_col4,#T_05f0e_row5_col5,#T_05f0e_row6_col6,#T_05f0e_row7_col7,#T_05f0e_row8_col8,#T_05f0e_row9_col9,#T_05f0e_row10_col10,#T_05f0e_row11_col11,#T_05f0e_row12_col12,#T_05f0e_row13_col13,#T_05f0e_row14_col14,#T_05f0e_row15_col15{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_05f0e_row0_col1,#T_05f0e_row0_col3,#T_05f0e_row0_col10,#T_05f0e_row1_col0,#T_05f0e_row6_col7,#T_05f0e_row7_col5,#T_05f0e_row7_col6,#T_05f0e_row7_col8,#T_05f0e_row7_col14,#T_05f0e_row8_col2,#T_05f0e_row8_col4,#T_05f0e_row8_col9,#T_05f0e_row8_col10,#T_05f0e_row8_col11,#T_05f0e_row8_col12,#T_05f0e_row8_col13,#T_05f0e_row8_col14,#T_05f0e_row8_col15{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_05f0e_row0_col2,#T_05f0e_row4_col0{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_05f0e_row0_col4,#T_05f0e_row8_col1{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_05f0e_row0_col5,#T_05f0e_row5_col2{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_05f0e_row0_col6,#T_05f0e_row2_col5{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_05f0e_row0_col7{
#             background-color:  #9ebeff;
#             color:  #000000;
#         }#T_05f0e_row0_col8,#T_05f0e_row6_col11,#T_05f0e_row12_col7,#T_05f0e_row15_col7{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_05f0e_row0_col9,#T_05f0e_row4_col8,#T_05f0e_row12_col0{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_05f0e_row0_col11,#T_05f0e_row3_col13{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_05f0e_row0_col12,#T_05f0e_row2_col15,#T_05f0e_row3_col14,#T_05f0e_row5_col15,#T_05f0e_row7_col12,#T_05f0e_row15_col2{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_05f0e_row0_col13,#T_05f0e_row0_col14,#T_05f0e_row6_col0{
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }#T_05f0e_row0_col15{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_05f0e_row1_col2{
#             background-color:  #f7b79b;
#             color:  #000000;
#         }#T_05f0e_row1_col3,#T_05f0e_row4_col2{
#             background-color:  #ef886b;
#             color:  #000000;
#         }#T_05f0e_row1_col4{
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }#T_05f0e_row1_col5,#T_05f0e_row1_col7,#T_05f0e_row1_col12{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_05f0e_row1_col6{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_05f0e_row1_col8,#T_05f0e_row2_col8,#T_05f0e_row9_col0,#T_05f0e_row10_col2,#T_05f0e_row15_col0,#T_05f0e_row15_col8{
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_05f0e_row1_col9,#T_05f0e_row1_col10,#T_05f0e_row3_col15,#T_05f0e_row4_col13,#T_05f0e_row4_col15,#T_05f0e_row8_col7,#T_05f0e_row12_col3{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_05f0e_row1_col11,#T_05f0e_row10_col14,#T_05f0e_row11_col14{
#             background-color:  #7597f6;
#             color:  #000000;
#         }#T_05f0e_row1_col13,#T_05f0e_row10_col3,#T_05f0e_row10_col8{
#             background-color:  #6180e9;
#             color:  #000000;
#         }#T_05f0e_row1_col14,#T_05f0e_row2_col10,#T_05f0e_row2_col13,#T_05f0e_row6_col13,#T_05f0e_row11_col2{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_05f0e_row1_col15,#T_05f0e_row5_col0,#T_05f0e_row7_col2,#T_05f0e_row15_col3{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_05f0e_row2_col0{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_05f0e_row2_col1{
#             background-color:  #f7b396;
#             color:  #000000;
#         }#T_05f0e_row2_col3,#T_05f0e_row3_col2{
#             background-color:  #f49a7b;
#             color:  #000000;
#         }#T_05f0e_row2_col4{
#             background-color:  #ee8468;
#             color:  #000000;
#         }#T_05f0e_row2_col6,#T_05f0e_row6_col1{
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }#T_05f0e_row2_col7,#T_05f0e_row10_col6{
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }#T_05f0e_row2_col9,#T_05f0e_row3_col10,#T_05f0e_row13_col0{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_05f0e_row2_col11,#T_05f0e_row5_col12,#T_05f0e_row6_col9,#T_05f0e_row9_col5,#T_05f0e_row14_col3,#T_05f0e_row14_col8{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_05f0e_row2_col12,#T_05f0e_row7_col4,#T_05f0e_row13_col3{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_05f0e_row2_col14,#T_05f0e_row10_col0{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_05f0e_row3_col0{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_05f0e_row3_col1{
#             background-color:  #ee8669;
#             color:  #000000;
#         }#T_05f0e_row3_col4{
#             background-color:  #e9785d;
#             color:  #000000;
#         }#T_05f0e_row3_col5{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_05f0e_row3_col6,#T_05f0e_row10_col9,#T_05f0e_row11_col10{
#             background-color:  #b7cff9;
#             color:  #000000;
#         }#T_05f0e_row3_col7,#T_05f0e_row6_col3{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_05f0e_row3_col8,#T_05f0e_row6_col2{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_05f0e_row3_col9,#T_05f0e_row4_col10,#T_05f0e_row6_col10,#T_05f0e_row6_col14,#T_05f0e_row9_col8{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_05f0e_row3_col11,#T_05f0e_row9_col14,#T_05f0e_row10_col1,#T_05f0e_row12_col1,#T_05f0e_row13_col1,#T_05f0e_row15_col14{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_05f0e_row3_col12,#T_05f0e_row5_col4,#T_05f0e_row10_col4,#T_05f0e_row12_col4,#T_05f0e_row14_col5{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_05f0e_row4_col1{
#             background-color:  #de614d;
#             color:  #000000;
#         }#T_05f0e_row4_col3{
#             background-color:  #e97a5f;
#             color:  #000000;
#         }#T_05f0e_row4_col5{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_05f0e_row4_col6{
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }#T_05f0e_row4_col7{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_05f0e_row4_col9,#T_05f0e_row11_col3{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_05f0e_row4_col11,#T_05f0e_row5_col3,#T_05f0e_row12_col14{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_05f0e_row4_col12,#T_05f0e_row8_col0,#T_05f0e_row13_col14{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_05f0e_row4_col14,#T_05f0e_row5_col9,#T_05f0e_row5_col10,#T_05f0e_row11_col0{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_05f0e_row5_col1,#T_05f0e_row6_col15,#T_05f0e_row9_col1,#T_05f0e_row15_col4,#T_05f0e_row15_col5{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_05f0e_row5_col6{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_05f0e_row5_col7,#T_05f0e_row5_col11,#T_05f0e_row9_col4,#T_05f0e_row11_col1,#T_05f0e_row11_col4,#T_05f0e_row11_col5,#T_05f0e_row13_col5{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_05f0e_row5_col8,#T_05f0e_row11_col7{
#             background-

# %%
x = moradias[['bedrooms', 'bathrooms', 'size_sqft']]
y = moradias[['rent']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.8, test_size = 0.2)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2831, 3)
# (708, 3)
# (2831, 1)
# (708, 1)

# %%
regressaoMultipla = LinearRegression()
regressaoMultipla.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_previsto = regressaoMultipla.predict(x_test)

# %%
#Coficiente de determinação (R²)
R2 = r2_score(y_test,y_previsto)
print(R2)
# Out:
# 0.7637959414060168

# %% [markdown]
# ## R² Ajustado

# %%
Image('r2_ajustado.png')

# %% [markdown]
# Em que N representa o número de amostras, enquanto p representa o número de features (variáveis de entrada do modelo). Podemos perceber que, quanto mais features utilizadas sem aumentar significativamente o valor de R², menor será nosso R-Quadrado Ajustado, o que nos garante uma medida menos enviesada e sempre menor do que o R-Quadrado.

# %%
#Coficiente de determinação ajustado (R²-Ajustado)
adj_r2 = (1 - ((1 - r2_score(y_test, y_previsto)) * (len(y_test) - 1)) / 
          (len(y_test) - x_train.shape[1] - 1))
print(adj_r2)
# Out:
# 0.7627893900199629

# %%
dadosImovel = [[4, 1, 3000]]

preco_aluguel = regressaoMultipla.predict(dadosImovel)

print("Previsão Aluguel: $%.2f" % preco_aluguel)
# Out:
# Previsão Aluguel: $13427.73

# %%
regressaoMultipla.coef_
# Out:
# array([[-380.71787589, 1437.30344155,    4.76969023]])

# %% [markdown]
# #### Os coeficientes são úteis para determinar qual variável independente tem mais peso. Por exemplo, um coeficiente de 1369.30 impactará o aluguel mais do que um coeficiente de -415.13, com o primeiro impactando os preços positivamente e o último negativamente.

# %%
y_previsto = regressaoMultipla.predict(x_test)

# %%
plt.scatter(y_test, y_previsto, c = 'b',  s = 50, alpha = 0.5)

plt.xlabel("Preços: $Y_i$")
plt.ylabel("Previsão Preços: $\hat{Y}_i$")
plt.title("Aluguel Real vs Aluguel Previsto")

plt.show()

# %%
plt.scatter(y_previsto, y_previsto - y_test, c = 'b',  s = 50, alpha = 0.5)
plt.axhline(y=0, color='r', linestyle='-')
plt.ylabel("Resíduo")
plt.title("Gráfico Residual ")
plt.show()

# %% [markdown]
# ## Outras métricas de avaliação do modelo

# %% [markdown]
# ### Erro Quadrático Médio (MSE)

# %%
Image('mse.png')

# %% [markdown]
# O MSE consiste na média do erro das previsões ao quadrado. Em outras palavras, pega-se a diferença entre o valor predito pelo modelo e o valor real, eleva-se o resultado ao quadrado, faz-se a mesma coisa com todos os outros pontos, soma-os, e dividi-se pelo número de elementos preditos. Quanto maior esse número, pior o modelo.

# %% [markdown]
# #### Vantagens e Desvantagens

# %% [markdown]
# Uma vez que essa métrica eleva o erro ao quadrado, predições muito distantes do real aumentam o valor da medida muito facilmente, o que a torna uma métrica de avaliação excelente para problemas nos quais grandes erros não são tolerados, como é o caso de exames médicos e projeções de preços.
#
# Entretanto, um ponto negativo do uso dessa métrica é sua falta de interpretabilidade direta, uma vez que, para a predição de valores de unidade u, a unidade do MSE seria u²

# %%
from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(y_test,y_previsto)
print("%.2f" %MSE)
# Out:
# 2357972.64

# %% [markdown]
# ### Raiz do erro quadrático médio (RMSE)

# %% [markdown]
# Tendo em vista essa diferença de unidades, o RMSE entra como uma forma de melhorar a interpretabilidade da métrica, acertando a unidade. Entretanto, essa medida, assim como o MSE, penaliza predições muito distantes da real.

# %%
Image('rmse.png')

# %%
RMSE = mean_squared_error(y_test,y_previsto,squared=False) 
# argumento 'squared' dado como false nos da o RMSE

# ou podemos simplesmente tirar a raiz quadrada do MSE
RMSE = MSE**0.5

print("%.2f" %RMSE)
# Out:
# 1535.57

# %% [markdown]
# ### Erro Percentual Absoluto Médio (MAPE)

# %% [markdown]
# Em contraste com as métricas anteriores, essa medida exprime uma porcentagem, obtida através da divisão da diferença entre predito (ŷ) e real pelo valor real (y).
#
# Assim como o MSE e o RMSE, quanto menor o valor, mais preciso seria o modelo de regressão.

# %%
Image('mape.png')

# %% [markdown]
# #### Por se tratar de uma porcentagem, essa métrica torna-se extremamente intuitiva, tanto para a interpretação do programador, quanto para a comunicação de resultados com pessoas sem conhecimento técnico. Por exemplo, ter um MAPE=12% significa que, em média, nosso modelo faz previsões que erram por 12% do valor real.

# %%
MAPE = np.mean(np.abs((y_test - y_previsto) / y_test)) * 100

print("Valor do MAPE %.2f" %MAPE+"%")
# Out:
# Valor do MAPE 20.88%
